# %%
import math

math.e
# Out:
# 2.718281828459045

# %% [markdown]
# **Round**

# %%
round(math.pi,2)
# Out:
# 3.14

# %%
a = 3.4
math.ceil(a)  #round of to higher integer
# Out:
# 4

# %%
math.floor(a)   #round of to lower integer
# Out:
# 3

# %%
b = 3.45678
math.trunc(b)
# Out:
# 3

# %%
math.exp(3)
# Out:
# 20.085536923187668

# %%
math.log(100)
# Out:
# 4.605170185988092

# %%
math.log(1000,10)
# Out:
# 2.9999999999999996

# %% [markdown]
# **Trignometric**

# %%
math.sin(math.pi/2)
# Out:
# 1.0

# %%
d = 90
math.sin(math.radians(d))
# Out:
# 1.0
